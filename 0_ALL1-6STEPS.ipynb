# %% [markdown]
# # Oceanographic Analysis - CalCOFI Capstone

# %%
from IPython.display import IFrame
embed = "https://docs.google.com/presentation/d/e/2PACX-1vTFUKkshFjS3SpFm392ru6L5CVemXbfU2Op1NaaEFiW16x4Je70wKbiR0u_TcR0UyqOiINeGCNVUquK/embed?"
IFrame(embed,frameborder="0", width="900", align="center", height="569", allowfullscreen="true", mozallowfullscreen="true", webkitallowfullscreen="true")
# Out:
#         <iframe
#             width="900"
#             height="569"
#             src="https://docs.google.com/presentation/d/e/2PACX-1vTFUKkshFjS3SpFm392ru6L5CVemXbfU2Op1NaaEFiW16x4Je70wKbiR0u_TcR0UyqOiINeGCNVUquK/embed??frameborder=0&align=center&allowfullscreen=true&mozallowfullscreen=true&webkitallowfullscreen=true"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # 1. Problem Identification

# %% [markdown]
# ###  <font color='blue'>Problem Statement</font>
# <strong>Help policy makers understand oceanographic trends to make intelligent choices that will save the marine ecosystem.</strong>
#
# ### Summary
# The California Cooperative Oceanic Fisheries Investigations (CalCOFI) are a unique partnership of the California Department of Fish & Wildlife, NOAA Fisheries Service and Scripps Institution of Oceanography. The organization was formed in 1949 to study the ecological aspects of the sardine population collapse off California. Today their focus has shifted to the study of the marine environment off the coast of California, the management of its living resources, and monitoring the indicators of El Nino and climate change. CalCOFI conducts quarterly cruises off southern & central California, collecting a suite of hydrographic and biological data on station and underway.  Data collected at depths down to 500 meters include: temperature, salinity, oxygen, phosphate, silicate, nitrate and nitrite, chlorophyll, transmissometer, PAR, C14 primary productivity, phytoplankton biodiversity, zooplankton biomass, and zooplankton biodiversity.
#
# ### Overview
# <p>Oceonography, the study of the biological features of the ocean, is important to determine the factors threatening the ocean and its marine life. Studying the ocean is also importance since it covers more than 70 percent of the surface of our planet.
# According to NASA, big shifts in salinity could be a warning that more severe droughts and floods are on their way, or even that global warming is speeding up.
# </p>
#
# ### Context
# Since climate changes today has been altering the ocean’s chemistry, it is important to understand the trends that are threatening the ocean and its marine life. The changes in temperature effects the melting of ice, and changes in sea levels and ocean currents.
# The migration pattern of marine species disrupts, and some marine species are on the verge of extinction.
#
# ### Criteria for Success
# Build a model that can accurately obtain and predict the factors affecting the ocean.
#
# ### Scope of Solution Space
# Determine the top 5 important features that are useful to predict the factors threatening the ocean.
# Build additional features out of existing data (Feature Engineering) and perform Exploratory Data Analysis.
#
# ### Constraints within Solution Space
# There are 61 features, but most of them have missing data.
#
# ### Data Acquisition and Key Data Sources
# The data is provided from CalCOFI
#
# https://calcofi.org/ccdata/database.html
#
# The following table includes the most important features of the dataset and their description.
#
# | | <strong>Features</strong> | <strong>Description</strong> |
# |------|------:|------|
# | 1 | Depthm | Depth of ocean in meters|
# | 2 | TempDegF | Temperature of Water in Fahrenheit|
# | 3 | Salinity | Salinity of water|
# | 4 | STheta | Potential Density of Water|

# %% [markdown]
# # 2. Data Wrangling
# - Collect, organize, define, and clean relevant datasets.

# %% [markdown]
# ## Data Collection

# %%
#Import necessary libraries
import pandas as pd
import numpy as np

# Plotting modules
import matplotlib.pyplot as plt
import seaborn as sns

# Analysing datetime
from datetime import datetime as dt
from datetime import timedelta

# File system manangement
import os,sys

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

#Interactive Shell
from IPython.core.interactiveshell import InteractiveShell  
InteractiveShell.ast_node_interactivity = "all"

#Pandas profiling
from pandas_profiling import ProfileReport

import missingno as msno
import re 

# %matplotlib inline

# %% [markdown]
# ## Workspace

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/asaadkhattab/Documents/DSProjects/OceanographicAnalysisCalCOFI

# %%
os.listdir(cwd)
#os.listdir( os.getcwd() )
# Out:
# ['.DS_Store',
#  'LICENSE',
#  '3_ExploratoryDataAnalysis.ipynb',
#  '0_ALL1-6STEPS.ipynb',
#  '2_DataWrangling.ipynb',
#  'models',
#  'README.md',
#  '1_ProblemIdentification.ipynb',
#  '.gitignore',
#  'figures',
#  '6_Documentation.ipynb',
#  '.ipynb_checkpoints',
#  '.git',
#  '4_Preprocessing_Modelling.ipynb',
#  'data']

# %% [markdown]
# ## Load the Data from CSV File

# %%
#KAGGLE.com
#path = '/kaggle/input/calcofi/bottle.csv'
#bottle = pd.read_csv(path)

# %%
# Import CSV file and read the dataset
path = '../data/calcofi/bottle.csv'
bottle = pd.read_csv(path, encoding='latin-1')

# %%
# Show all columns
pd.set_option('max_columns', None)

# %% [markdown]
# #### First 5 rows

# %%
bottle.head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  O2ml_L  STheta  O2Sat  Oxy_µmol/Kg  BtlNum  RecInd  \
# 0       0   10.50  33.440     NaN  25.649    NaN          NaN     NaN       3
# 1       8   10.46  33.440     NaN  25.656    NaN          NaN     NaN       3
# 2      10   10.46  33.437     NaN  25.654    NaN          NaN     NaN       7
# 3      19   10.45  33.420     NaN  25.643    NaN          NaN     NaN       3
# 4      20   10.45  33.421     NaN  25.643    NaN          NaN     NaN       7
#
#    T_prec  T_qual  S_prec  S_qual  P_qual  O_qual  SThtaq  O2Satq  ChlorA  \
# 0     1.0     NaN     2.0     NaN     9.0     9.0     NaN     9.0     NaN
# 1     2.0     NaN     2.0     NaN     9.0     9.0     NaN     9.0     NaN
# 2     2.0     NaN     3.0     NaN     9.0     9.0     NaN     9.0     NaN
# 3     2.0     NaN     2.0     NaN     9.0     9.0     NaN     9.0     NaN
# 4     2.0     NaN     3.0     NaN     9.0     9.0     NaN     9.0     NaN
#
#    Chlqua  Phaeop  Phaqua  PO4uM  PO4q  SiO3uM  SiO3qu  NO2uM  NO2q  NO3uM  \
# 0     9.0     NaN     9.0    NaN   9.0     NaN     9.0    NaN   9.0    NaN
# 1     9.0     NaN     9.0    NaN   9.0     NaN     9.0    NaN   9.0    NaN
# 2     9.0     NaN     9.0    NaN   9.0     NaN     9.0    NaN   9.0    NaN
# 3     9.0     NaN     9.0    NaN   9.0     NaN     9.0    NaN   9.0    NaN
# 4     9.0     NaN     9.0    NaN   9.0     NaN     9.0    NaN   9.0    NaN
#
#    NO3q  NH3uM  NH3q  C14As1  C14A1p  C14A1q  C14As2  C14A2p  C14A2q  DarkAs  \
# 0   9.0    NaN   9.0     NaN     NaN     9.0     NaN     NaN     9.0     NaN
# 1   9.0    NaN   9.0     NaN     NaN     9.0     NaN     NaN     9.0     NaN
# 2   9.0    NaN   9.0     NaN     NaN     9.0     NaN     NaN     9.0     NaN
# 3   9.0    NaN   9.0     NaN     NaN     9.0     NaN     NaN     9.0     NaN
# 4   9.0    NaN   9.0     NaN     NaN     9.0     NaN     NaN     9.0     NaN
#
#    DarkAp  DarkAq  MeanAs  MeanAp  MeanAq IncTim  LightP  R_Depth  R_TEMP  \
# 0     NaN     9.0     NaN     NaN     9.0    NaN     NaN      0.0   10.50
# 1     NaN     9.0     NaN     NaN     9.0    NaN     NaN      8.0   10.46
# 2     NaN     9.0     NaN     NaN     9.0    NaN     NaN     10.0   10.46
# 3     NaN     9.0     NaN     NaN     9.0    NaN     NaN     19.0   10.45
# 4     NaN     9.0     NaN     NaN     9.0    NaN     NaN     20.0   10.45
#
#    R_Sal  R_DYNHT  R_Nuts  R_Oxy_µmol/Kg  DIC1  DIC2  TA1  TA2  pH1  pH2  \
# 0  233.0     0.00     NaN            NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 1  232.5     0.01     NaN            NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 2  232.8     0.02     NaN            NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 3  234.1     0.04     NaN            NaN   NaN   NaN  NaN  NaN  NaN  NaN
# 4  234.0     0.04     NaN            NaN   NaN   NaN  NaN  NaN  NaN  NaN
#
#   DIC Quality Comment
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN

# %% [markdown]
# #### Last 3 rows

# %%
bottle.tail(3)
# Out:
#         Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 887015    35272   887016  093.4 026.4  20-1911OC-MX-308-2233-09340264-0006A-3
# 887016    35272   887017  093.4 026.4  20-1911OC-MX-308-2233-09340264-0010A-7
# 887017    35272   887018  093.4 026.4  20-1911OC-MX-308-2233-09340264-0011A-3
#
#         Depthm  T_degC   Salnty  O2ml_L    STheta   O2Sat  Oxy_µmol/Kg  \
# 887015       6  17.278  33.6271   6.058  24.39638  110.47       264.11
# 887016      10  17.177  33.6199   5.985  24.41515  108.91       260.92
# 887017      11  17.145  33.6187   5.921  24.42188  107.69       258.13
#
#         BtlNum  RecInd  T_prec  T_qual  S_prec  S_qual  P_qual  O_qual  \
# 887015     2.0       3     2.0     NaN     3.0     NaN     NaN     NaN
# 887016     NaN       7     2.0     NaN     3.0     6.0     NaN     6.0
# 887017     1.0       3     2.0     NaN     3.0     NaN     NaN     NaN
#
#         SThtaq  O2Satq  ChlorA  Chlqua  Phaeop  Phaqua  PO4uM  PO4q  SiO3uM  \
# 887015     NaN     NaN   2.664     NaN   0.587     NaN   0.21   NaN    2.40
# 887016     6.0     6.0   3.178     NaN   0.708     NaN   0.25   NaN    2.70
# 887017     NaN     NaN   3.306     NaN   0.738     NaN   0.26   NaN    2.77
#
#         SiO3qu  NO2uM  NO2q  NO3uM  NO3q  NH3uM  NH3q  C14As1  C14A1p  C14A1q  \
# 887015     NaN  0.000   8.0    0.0   8.0   0.24   NaN     NaN     NaN     9.0
# 887016     NaN    NaN   9.0    0.0   8.0   0.61   NaN     NaN     NaN     9.0
# 887017     NaN  0.028   NaN    0.0   8.0   0.70   NaN     NaN     NaN     9.0
#
#         C14As2  C14A2p  C14A2q  DarkAs  DarkAp  DarkAq  MeanAs  MeanAp  \
# 887015     NaN     NaN     9.0     NaN     NaN     9.0     NaN     NaN
# 887016     NaN     NaN     9.0     NaN     NaN     9.0     NaN     NaN
# 887017     NaN     NaN     9.0     NaN     NaN     9.0     NaN     NaN
#
#         MeanAq IncTim  LightP  R_Depth  R_TEMP  R_Sal  R_DYNHT  R_Nuts  \
# 887015     9.0    NaN     NaN      6.0   17.28  352.5    0.022    0.24
# 887016     9.0    NaN     NaN     10.0   17.18  350.8    0.032    0.61
# 887017     9.0    NaN     NaN     11.0   17.14  350.2    0.039    0.70
#
#         R_Oxy_µmol/Kg  DIC1  DIC2  TA1  TA2  pH1  pH2 DIC Quality Comment
# 887015         264.11   NaN   NaN  NaN  NaN  NaN  NaN                 NaN
# 887016         260.92   NaN   NaN  NaN  NaN  NaN  NaN                 NaN
# 887017         258.13   NaN   NaN  NaN  NaN  NaN  NaN                 NaN

# %% [markdown]
# ### Functions

# %%
# Convert Celcius to Fahr
def cel_to_fahr(x):
    x = x * 1.8 + 32
    return float(x)

# %%
# Dimensions of the dataset. #(samples,features)
print("There are", bottle.shape[0], "Rows(Observations).")
print("There are", bottle.shape[1], "Columns(Features).")
bottle.shape
# Out:
# There are 887018 Rows(Observations).
# There are 62 Columns(Features).
# (887018, 62)

# %% [markdown]
# ___

# %% [markdown]
# ## Data Organization

# %% [markdown]
# #### Create SubFolders

# %%
newfolder = "../OceanographicAnalysisCalCOFI/data"

try:
    os.mkdir(newfolder)
except OSError:
    print ("Creation of the directory %s failed" % newfolder)
else:
    print ("Successfully created the directory %s " % newfolder)
# Out:
# Creation of the directory ../OceanographicAnalysisCalCOFI/data failed

# %%
newfolder = "../OceanographicAnalysisCalCOFI/figures"

try:
    os.mkdir(newfolder)
except OSError:
    print ("Creation of the directory %s failed" % newfolder)
else:
    print ("Successfully created the directory %s " % newfolder)
# Out:
# Creation of the directory ../OceanographicAnalysisCalCOFI/figures failed

# %%
newfolder = "../OceanographicAnalysisCalCOFI/models"

try:
    os.mkdir(newfolder)
except OSError:
    print ("Creation of the directory %s failed" % newfolder)
else:
    print ("Successfully created the directory %s " % newfolder)
# Out:
# Creation of the directory ../OceanographicAnalysisCalCOFI/models failed

# %% [markdown]
# ---

# %% [markdown]
# ## Data Definition

# %% [markdown]
# ### Explore the Data

# %%
# Get DataFrame Information
bottle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887018 entries, 0 to 887017
# Data columns (total 62 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Cst_Cnt              887018 non-null  int64
#  1   Btl_Cnt              887018 non-null  int64
#  2   Sta_ID               887018 non-null  object
#  3   Depth_ID             887018 non-null  object
#  4   Depthm               887018 non-null  int64
#  5   T_degC               876053 non-null  float64
#  6   Salnty               839663 non-null  float64
#  7   O2ml_L               717589 non-null  float64
#  8   STheta               834327 non-null  float64
#  9   O2Sat                682668 non-null  float64
#  10  Oxy_µmol/Kg          682657 non-null  float64
#  11  BtlNum               133892 non-null  float64
#  12  RecInd               887018 non-null  int64
#  13  T_prec               876055 non-null  float64
#  14  T_qual               23129 non-null   float64
#  15  S_prec               839663 non-null  float64
#  16  S_qual               81802 non-null   float64
#  17  P_qual               673756 non-null  float64
#  18  O_qual               195017 non-null  float64
#  19  SThtaq               72726 non-null   float64
#  20  O2Satq               228133 non-null  float64
#  21  ChlorA               240027 non-null  float64
#  22  Chlqua               646628 non-null  float64
#  23  Phaeop               240026 non-null  float64
#  24  Phaqua               646632 non-null  float64
#  25  PO4uM                433429 non-null  float64
#  26  PO4q                 453832 non-null  float64
#  27  SiO3uM               374205 non-null  float64
#  28  SiO3qu               512983 non-null  float64
#  29  NO2uM                357429 non-null  float64
#  30  NO2q                 543565 non-null  float64
#  31  NO3uM                357518 non-null  float64
#  32  NO3q                 535783 non-null  float64
#  33  NH3uM                84329 non-null   float64
#  34  NH3q                 825936 non-null  float64
#  35  C14As1               15440 non-null   float64
#  36  C14A1p               12760 non-null   float64
#  37  C14A1q               869746 non-null  float64
#  38  C14As2               15422 non-null   float64
#  39  C14A2p               12742 non-null   float64
#  40  C14A2q               869764 non-null  float64
#  41  DarkAs               23657 non-null   float64
#  42  DarkAp               20457 non-null   float64
#  43  DarkAq               861581 non-null  float64
#  44  MeanAs               23658 non-null   float64
#  45  MeanAp               20457 non-null   float64
#  46  MeanAq               861580 non-null  float64
#  47  IncTim               15445 non-null   object
#  48  LightP               19662 non-null   float64
#  49  R_Depth              887017 non-null  float64
#  50  R_TEMP               840969 non-null  float64
#  51  R_Sal                834240 non-null  float64
#  52  R_DYNHT              840354 non-null  float64
#  53  R_Nuts               84349 non-null   float64
#  54  R_Oxy_µmol/Kg        682657 non-null  float64
#  55  DIC1                 1999 non-null    float64
#  56  DIC2                 224 non-null     float64
#  57  TA1                  2084 non-null    float64
#  58  TA2                  234 non-null     float64
#  59  pH1                  84 non-null      float64
#  60  pH2                  10 non-null      float64
#  61  DIC Quality Comment  55 non-null      object
# dtypes: float64(54), int64(4), object(4)
# memory usage: 419.6+ MB

# %% [markdown]
# There are no missing values. AppointmentDay and ScheduledDay should be converted to datetime. There are 3 objects (Gender, Neighborhood, and No-show)

# %% [markdown]
# #### Variable Types

# %%
bottle.dtypes.value_counts()
# Out:
# float64    54
# object      4
# int64       4
# dtype: int64

# %%
print(bottle.columns)
# Out:
# Index(['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'T_degC',
#        'Salnty', 'O2ml_L', 'STheta', 'O2Sat', 'Oxy_µmol/Kg', 'BtlNum',
#        'RecInd', 'T_prec', 'T_qual', 'S_prec', 'S_qual', 'P_qual', 'O_qual',
#        'SThtaq', 'O2Satq', 'ChlorA', 'Chlqua', 'Phaeop', 'Phaqua', 'PO4uM',
#        'PO4q', 'SiO3uM', 'SiO3qu', 'NO2uM', 'NO2q', 'NO3uM', 'NO3q', 'NH3uM',
#        'NH3q', 'C14As1', 'C14A1p', 'C14A1q', 'C14As2', 'C14A2p', 'C14A2q',
#        'DarkAs', 'DarkAp', 'DarkAq', 'MeanAs', 'MeanAp', 'MeanAq', 'IncTim',
#        'LightP', 'R_Depth', 'R_TEMP', 'R_Sal', 'R_DYNHT', 'R_Nuts',
#        'R_Oxy_µmol/Kg', 'DIC1', 'DIC2', 'TA1', 'TA2', 'pH1', 'pH2',
#        'DIC Quality Comment'],
#       dtype='object')

# %% [markdown]
# # Handling Missing Values

# %%
#Counts and percentage of null values 
dictionary = {
    "NullCount":bottle.isnull().sum().sort_values(ascending=False),
    "NullPercent":bottle.isnull().sum().sort_values(ascending=False)/len(bottle)*100
}

na_df = pd.DataFrame(dictionary)
na_df.columns = ['NullCount','NullPercent']
na_df[(na_df['NullCount'] > 0)].reset_index()
# Out:
#                   index  NullCount  NullPercent
# 0                   pH2     887008    99.998873
# 1   DIC Quality Comment     886963    99.993799
# 2                   pH1     886934    99.990530
# 3                  DIC2     886794    99.974747
# 4                   TA2     886784    99.973619
# 5                  DIC1     885019    99.774638
# 6                   TA1     884934    99.765056
# 7                C14A2p     874276    98.563502
# 8                C14A1p     874258    98.561472
# 9                C14As2     871596    98.261366
# 10               C14As1     871578    98.259336
# 11               IncTim     871573    98.258773
# 12               LightP     867356    97.783360
# 13               DarkAp     866561    97.693733
# 14               MeanAp     866561    97.693733
# 15               T_qual     863889    97.392499
# 16               DarkAs     863361    97.332974
# 17               MeanAs     863360    97.332861
# 18               SThtaq     814292    91.801068
# 19               S_qual     805216    90.777865
# 20                NH3uM     802689    90.492978
# 21               R_Nuts     802669    90.490723
# 22               BtlNum     753126    84.905380
# 23               O_qual     692001    78.014313
# 24               O2Satq     658885    74.280905
# 25               Phaeop     646992    72.940121
# 26               ChlorA     646991    72.940008
# 27                NO2uM     529589    59.704425
# 28                NO3uM     529500    59.694392
# 29               SiO3uM     512813    57.813145
# 30                PO4uM     453589    51.136392
# 31                 PO4q     433186    48.836213
# 32               SiO3qu     374035    42.167690
# 33                 NO3q     351235    39.597280
# 34                 NO2q     343453    38.719958
# 35               Chlqua     240390    27.100916
# 36               Phaqua     240386    27.100465
# 37               P_qual     213262    24.042579
# 38          Oxy_µmol/Kg     204361    23.039104
# 39        R_Oxy_µmol/Kg     204361    23.039104
# 40                O2Sat     204350    23.037864
# 41               O2ml_L     169429    19.100965
# 42                 NH3q      61082     6.886219
# 43                R_Sal      52778     5.950048
# 44               STheta      52691     5.940240
# 45               S_prec      47355     5.338674
# 46               Salnty      47355     5.338674
# 47              R_DYNHT      46664     5.260773
# 48               R_TEMP      46049     5.191439
# 49               MeanAq      25438     2.867811
# 50               DarkAq      25437     2.867698
# 51               C14A1q      17272     1.947198
# 52               C14A2q      17254     1.945169
# 53               T_degC      10965     1.236164
# 54               T_prec      10963     1.235939
# 55              R_Depth          1     0.000113

# %% [markdown]
# On line 40 in the previous DataFrame we see that O2ml_L is missing 19.10% of data.  So we will delete all rows that has more than 19% of missing data.

# %%
pct_null = bottle.isnull().sum() / len(bottle)
missing_features = pct_null[pct_null > 0.19].index
bottle.drop(missing_features, axis=1, inplace=True)
df = bottle

# %%
# Visualize Missingness
msno.matrix(df)
plt.show()
# Out:
# <AxesSubplot:>

# %%
print ( df.nunique() / df.shape[0] * 100 )
# Out:
# Cst_Cnt       3.976469
# Btl_Cnt     100.000000
# Sta_ID        0.296950
# Depth_ID     99.997520
# Depthm        0.362901
# T_degC        1.718680
# Salnty        1.766255
# STheta        6.213741
# RecInd        0.000564
# T_prec        0.000451
# S_prec        0.000225
# NH3q          0.000225
# C14A1q        0.000225
# C14A2q        0.000225
# DarkAq        0.000225
# MeanAq        0.000225
# R_Depth       0.375190
# R_TEMP        0.322090
# R_Sal         0.592547
# R_DYNHT       0.208451
# dtype: float64

# %%
df.head()
# Out:
#    Cst_Cnt  Btl_Cnt       Sta_ID                                Depth_ID  \
# 0        1        1  054.0 056.0  19-4903CR-HY-060-0930-05400560-0000A-3
# 1        1        2  054.0 056.0  19-4903CR-HY-060-0930-05400560-0008A-3
# 2        1        3  054.0 056.0  19-4903CR-HY-060-0930-05400560-0010A-7
# 3        1        4  054.0 056.0  19-4903CR-HY-060-0930-05400560-0019A-3
# 4        1        5  054.0 056.0  19-4903CR-HY-060-0930-05400560-0020A-7
#
#    Depthm  T_degC  Salnty  STheta  RecInd  T_prec  S_prec  NH3q  C14A1q  \
# 0       0   10.50  33.440  25.649       3     1.0     2.0   9.0     9.0
# 1       8   10.46  33.440  25.656       3     2.0     2.0   9.0     9.0
# 2      10   10.46  33.437  25.654       7     2.0     3.0   9.0     9.0
# 3      19   10.45  33.420  25.643       3     2.0     2.0   9.0     9.0
# 4      20   10.45  33.421  25.643       7     2.0     3.0   9.0     9.0
#
#    C14A2q  DarkAq  MeanAq  R_Depth  R_TEMP  R_Sal  R_DYNHT
# 0     9.0     9.0     9.0      0.0   10.50  233.0     0.00
# 1     9.0     9.0     9.0      8.0   10.46  232.5     0.01
# 2     9.0     9.0     9.0     10.0   10.46  232.8     0.02
# 3     9.0     9.0     9.0     19.0   10.45  234.1     0.04
# 4     9.0     9.0     9.0     20.0   10.45  234.0     0.04

# %% [markdown]
# ### Rename Columns

# %%
df.columns
# Out:
# Index(['Cst_Cnt', 'Btl_Cnt', 'Sta_ID', 'Depth_ID', 'Depthm', 'T_degC',
#        'Salnty', 'STheta', 'RecInd', 'T_prec', 'S_prec', 'NH3q', 'C14A1q',
#        'C14A2q', 'DarkAq', 'MeanAq', 'R_Depth', 'R_TEMP', 'R_Sal', 'R_DYNHT'],
#       dtype='object')

# %%
df = df.rename(columns = { 
    "Cst_Cnt": "CastCount",
    "Btl_Cnt": "BottleCount",
    "Depthm": "DepthMeters",
    "T_degC": "TempDegC",
    "Salnty": "Salinity",    
    "STheta": "PDensity"
    
})

# %% [markdown]
# ### Set BottleCount to be Index

# %%
df = df.set_index('BottleCount')

# %% [markdown]
# ### Extract Year and Month from Depth_ID

# %%
# Extract Year
search = []    

for values in df['Depth_ID']:
    search.append(re.search(r'\d{2}-\d{2}', values).group())
    
df['Year'] = search
df['Year'] = df['Year'].replace(to_replace='-',value='', regex = True) 

df['Year'] = pd.to_datetime(df['Year']).values.astype('datetime64[Y]')
df['Year'] =  pd.DatetimeIndex(df['Year']).year

# %%
# Extract Month 
search = []    

for values in df['Depth_ID']:
    search.append(re.search(r'-\d+', values).group())
    
df['Month'] = search
df['Month'] = df['Month'].str[-2:]

df['Month'] = df['Month'].astype('int64')

# %% [markdown]
# ### Convert from Celsius to Fahrenheit

# %%
df['TempDegF'] = df['TempDegC'].apply(cel_to_fahr)
df = df.drop("TempDegC", axis = 1)

# %%
print('Salinity:', df.Salinity.unique() ) 
print('TempDegF:', df.TempDegF.unique() )
# Out:
# Salinity: [33.44   33.437  33.42   ... 34.0373 33.8616 33.7855]
# TempDegF: [50.9    50.828  50.81   ... 68.4482 68.4536 63.1004]

# %% [markdown]
# ## Dataset Statistics

# %%
df.describe(include="all").T
# Out:
#               count  unique                                     top   freq  \
# CastCount    887018     NaN                                     NaN    NaN
# Sta_ID       887018    2634                             090.0 070.0  10417
# Depth_ID     887018  886996  20-1911OC-PR-319-1837-08000600-0013B-6      2
# DepthMeters  887018     NaN                                     NaN    NaN
# Salinity     839663     NaN                                     NaN    NaN
# PDensity     834327     NaN                                     NaN    NaN
# RecInd       887018     NaN                                     NaN    NaN
# T_prec       876055     NaN                                     NaN    NaN
# S_prec       839663     NaN                                     NaN    NaN
# NH3q         825936     NaN                                     NaN    NaN
# C14A1q       869746     NaN                                     NaN    NaN
# C14A2q       869764     NaN                                     NaN    NaN
# DarkAq       861581     NaN                                     NaN    NaN
# MeanAq       861580     NaN                                     NaN    NaN
# R_Depth      887017     NaN                                     NaN    NaN
# R_TEMP       840969     NaN                                     NaN    NaN
# R_Sal        834240     NaN                                     NaN    NaN
# R_DYNHT      840354     NaN                                     NaN    NaN
# Year         887018     NaN                                     NaN    NaN
# Month        887018     NaN                                     NaN    NaN
# TempDegF     876053     NaN                                     NaN    NaN
#
#                  mean         std      min     25%     50%      75%      max
# CastCount       17581       10483        1    8462   17463    27190    35272
# Sta_ID            NaN         NaN      NaN     NaN     NaN      NaN      NaN
# Depth_ID          NaN         NaN      NaN     NaN     NaN      NaN      NaN
# DepthMeters   225.038       313.2        0      45     125      300     5351
# Salinity      33.8378    0.459417  28.3652  33.487   33.86  34.1912   37.034
# PDensity      25.8153     1.16246   20.934  24.961   25.99   26.643  250.784
# RecInd         4.6921     1.87779        3       3       3        7        7
# T_prec        2.01673    0.147012        1       2       2        2        9
# S_prec        2.72426    0.446887        2       2       3        3        3
# NH3q          8.85888    0.828058        4       9       9        9        9
# C14A1q        8.99999  0.00283695        8       9       9        9        9
# C14A2q        8.99999  0.00283692        8       9       9        9        9
# DarkAq        8.99999  0.00285036        8       9       9        9        9
# MeanAq        8.99999  0.00285036        8       9       9        9        9
# R_Depth       226.594     316.569        0      45     126      302     5458
# R_TEMP        10.8562     4.22591        0    7.75   10.11    13.94    31.14
# R_Sal         221.307     93.3373      0.4     144   203.7    300.2    683.4
# R_DYNHT      0.429753    0.380306        0    0.13    0.34     0.63     3.88
# Year          1975.22     21.2032     1949    1956    1972     1992     2093
# Month         6.52558     5.98896        1       3       6        9       95
# TempDegF      51.4662     7.62027   34.592   45.86  50.126    57.02   88.052

# %% [markdown]
# ___

# %% [markdown]
# ## Detect Anomalies & Outliers

# %% [markdown]
# #### Range of values per column

# %%
range = df.aggregate([min, max])
print(range)
# Out:
#      CastCount       Sta_ID                                Depth_ID  \
# min          1  001.0 168.0  19-4903CR-HY-060-0930-05400560-0000A-3
# max      35272  176.7 030.0  20-93.3OC-MX-311-1010-09331100-0515A-3
#
#      DepthMeters  Salinity  PDensity  RecInd  T_prec  S_prec  NH3q  C14A1q  \
# min            0   28.3652    20.934       3     1.0     2.0   4.0     8.0
# max         5351   37.0340   250.784       7     9.0     3.0   9.0     9.0
#
#      C14A2q  DarkAq  MeanAq  R_Depth  R_TEMP  R_Sal  R_DYNHT  Year  Month  \
# min     8.0     8.0     8.0      0.0    0.00    0.4     0.00  1949      1
# max     9.0     9.0     9.0   5458.0   31.14  683.4     3.88  2093     95
#
#      TempDegF
# min    34.592
# max    88.052

# %% [markdown]
# ### Year - Month

# %%
sns.boxplot(x='Year',data=df)
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# Currently, we are in 2020. We will remove all the years after that including 2093

# %%
df['Year'] = df['Year'].drop(df[df['Year']>2020].index)

# %% [markdown]
# The dataset has months of more than 12, so we will drop them too.

# %%
df['Month'] = df['Month'].drop(df[df['Month']>12].index)

# %%
df["Salinity"].describe(include="all").T
# Out:
# count    839663.000000
# mean         33.837784
# std           0.459417
# min          28.365200
# 25%          33.487000
# 50%          33.860000
# 75%          34.191200
# max          37.034000
# Name: Salinity, dtype: float64

# %%
df["TempDegF"].describe(include="all").T
# Out:
# count    876053.000000
# mean         51.466178
# std           7.620268
# min          34.592000
# 25%          45.860000
# 50%          50.126000
# 75%          57.020000
# max          88.052000
# Name: TempDegF, dtype: float64

# %% [markdown]
# #### Check for Duplicated Rows

# %%
duplicateRowsDF = df.duplicated() 
df[duplicateRowsDF]
# Out:
#              CastCount       Sta_ID                                Depth_ID  \
# BottleCount
# 858746           34170  063.3 090.0  20-16045S-MX-110-2018-06330900-0002A-3
# 858747           34170  063.3 090.0  20-16045S-MX-110-2018-06330900-0010A-3
# 858748           34170  063.3 090.0  20-16045S-MX-110-2018-06330900-0025A-3
# 858749           34170  063.3 090.0  20-16045S-MX-110-2018-06330900-0063A-3
# 858750           34170  063.3 090.0  20-16045S-MX-110-2018-06330900-0088A-3
# 858880           34176  066.7 090.0  20-16045S-MX-110-1421-06670900-0003A-3
# 858881           34176  066.7 090.0  20-16045S-MX-110-1421-06670900-0011A-3
# 858882           34176  066.7 090.0  20-16045S-MX-110-1421-06670900-0026A-3
# 858883           34176  066.7 090.0  20-16045S-MX-110-1421-06670900-0061A-3
# 858884           34176  066.7 090.0  20-16045S-MX-110-1421-06670900-0088A-3
# 886343           35248  090.0 053.0  20-1911OC-MX-313-1236-09000530-0002A-3
# 886344           35248  090.0 053.0  20-1911OC-MX-313-1236-09000530-0010B-6
# 886345           35248  090.0 053.0  20-1911OC-MX-313-1236-09000530-0010A-3
# 886346           35248  090.0 053.0  20-1911OC-MX-313-1236-09000530-0020A-3
# 886347           35248  090.0 053.0  20-1911OC-MX-313-1236-09000530-0030B-6
#
#              DepthMeters  Salinity  PDensity  RecInd  T_prec  S_prec  NH3q  \
# BottleCount
# 858746                 2   32.9637  24.19060       3     2.0     3.0   9.0
# 858747                10   32.9630  24.24324       3     2.0     3.0   9.0
# 858748                25   32.9851  24.39601       3     2.0     3.0   9.0
# 858749                63   32.9274  24.50110       3     2.0     3.0   9.0
# 858750                88   33.0018  24.69834       3     2.0     3.0   9.0
# 858880                 3   32.9452  24.29040       3     2.0     3.0   9.0
# 858881                11   32.9441  24.35396       3     2.0     3.0   9.0
# 858882                26   32.9534  24.49039       3     2.0     3.0   9.0
# 858883                61   32.9589  24.63745       3     2.0     3.0   9.0
# 858884                88   33.2387  25.26541       3     2.0     3.0   9.0
# 886343                 2   33.6809  24.26980       3     2.0     3.0   NaN
# 886344                 9   33.6761  24.26750       6     2.0     3.0   9.0
# 886345                10   33.6810  24.27130       3     2.0     3.0   4.0
# 886346                20   33.6721  24.26770       3     2.0     3.0   4.0
# 886347                30   33.5654  24.75280       6     2.0     3.0   9.0
#
#              C14A1q  C14A2q  DarkAq  MeanAq  R_Depth  R_TEMP  R_Sal  R_DYNHT  \
# BottleCount
# 858746          9.0     9.0     9.0     9.0      2.0   15.96  371.9    0.007
# 858747          9.0     9.0     9.0     9.0     10.0   15.73  367.2    0.034
# 858748          9.0     9.0     9.0     9.0     25.0   15.11  353.1    0.088
# 858749          9.0     9.0     9.0     9.0     64.0   14.42  344.3    0.222
# 858750          9.0     9.0     9.0     9.0     89.0   13.75  326.2    0.307
# 858880          9.0     9.0     9.0     9.0      3.0   15.45  362.5    0.005
# 858881          9.0     9.0     9.0     9.0     11.0   15.16  356.7    0.035
# 858882          9.0     9.0     9.0     9.0     26.0   14.56  344.1    0.087
# 858883          9.0     9.0     9.0     9.0     62.0   13.88  331.2    0.207
# 858884          9.0     9.0     9.0     9.0     89.0   11.78  271.9    0.293
# 886343          9.0     9.0     9.0     9.0      2.0   17.97  364.4    0.007
# 886344          9.0     9.0     9.0     9.0     10.0   17.97  364.9    0.036
# 886345          9.0     9.0     9.0     9.0     10.0   17.97  364.6    0.037
# 886346          9.0     9.0     9.0     9.0     20.0   17.96  365.3    0.073
# 886347          9.0     9.0     9.0     9.0     30.0   15.52  319.4    0.108
#
#                Year  Month  TempDegF
# BottleCount
# 858746       2016.0    NaN   60.7370
# 858747       2016.0    NaN   60.3140
# 858748       2016.0    NaN   59.2106
# 858749       2016.0    NaN   57.9704
# 858750       2016.0    NaN   56.7680
# 858880       2016.0    NaN   59.8154
# 858881       2016.0    NaN   59.2898
# 858882       2016.0    NaN   58.2134
# 858883       2016.0    NaN   56.9984
# 858884       2016.0    NaN   53.2202
# 886343       2019.0   11.0   64.3514
# 886344       2019.0   11.0   64.3460
# 886345       2019.0   11.0   64.3460
# 886346       2019.0   11.0   64.3280
# 886347       2019.0   11.0   59.9522

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (887003, 21)

# %% [markdown]
# ---

# %% [markdown]
# #  3. EXPLORATORY DATA ANALYSIS

# %% [markdown]
# #### Categorical columns and their associated levels.

# %%
dfo = df.select_dtypes(include=['object'], exclude=['datetime'])
dfo.shape
#get levels for all variables
vn = pd.DataFrame(dfo.nunique()).reset_index()
vn.columns = ['VarName', 'LevelsCount']
vn.sort_values(by='LevelsCount', ascending = False)
# Out:
# (887003, 2)
#     VarName  LevelsCount
# 1  Depth_ID       886996
# 0    Sta_ID         2634

# %%
df = df.drop(['Depth_ID','Sta_ID'],axis=1)

# %%
corr = df.corr()

plt.figure(figsize=(20,10))
sns.heatmap(corr,
            linecolor='blue',linewidths=.1, 
            cmap="YlGnBu", annot=True)
plt.yticks(rotation=0);

# %% [markdown]
# C14A1q, C14A2q, DarkAq, and MeanAq all have a high correlation so we will keep MeanAq. The Reported Depth, Salinity, temp, and R_DYNHT have a positive correlation with the actual findings so we will only keep the Reported Dynamic Height.

# %%
df = df.drop(['CastCount','R_Depth','R_TEMP', 'R_Sal', 'C14A1q', 'C14A2q', 'DarkAq' ], axis=1)

# %% [markdown]
# # 4. PreProcessing

# %%
from sklearn.preprocessing import StandardScaler

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

# %% [markdown]
# ## SimpleImputer

# %%
numeric_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy='mean')),
        ('scaler', StandardScaler())
])

numeric_features = df.select_dtypes(include=['int64', 'float64']).columns

preprocessor = ColumnTransformer(
    remainder='passthrough',
    transformers=[
        ('num', numeric_transformer, numeric_features),
    ]
)

steps = [('preprocessor', preprocessor)]

pipeline = Pipeline(steps)

pipeline.fit(df[:])
df_pipe = pipeline.transform(df[:])
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['DepthMeters', 'Salinity', 'PDensity', 'RecInd', 'T_prec', 'S_prec',
#        'NH3q', 'MeanAq', 'R_DYNHT', 'Year', 'Month', 'TempDegF'],
#       dtype='object'))]))])

# %%
df_pipe = pd.DataFrame(df_pipe)
df_pipe
# Out:
#                0         1         2         3         4         5         6  \
# 0      -0.718520 -0.889962 -0.147495 -0.901126 -6.959051 -1.665733  0.176604
# 1      -0.692977 -0.889962 -0.141286 -0.901126 -0.114516 -1.665733  0.176604
# 2      -0.686591 -0.896674 -0.143060  1.229039 -0.114516  0.634194  0.176604
# 3      -0.657856 -0.934707 -0.152816 -0.901126 -0.114516 -1.665733  0.176604
# 4      -0.654663 -0.932470 -0.152816  1.229039 -0.114516  0.634194  0.176604
# ...          ...       ...       ...       ...       ...       ...       ...
# 886998 -0.718520 -0.466677 -1.366607  1.229039 -0.114516  0.634194  0.000000
# 886999 -0.712134 -0.466677 -1.366465 -0.901126 -0.114516  0.634194  0.000000
# 887000 -0.699363 -0.471375 -1.258562 -0.901126 -0.114516  0.634194  0.000000
# 887001 -0.686591 -0.487483 -1.241913  1.229039 -0.114516  0.634194  0.000000
# 887002 -0.683398 -0.490168 -1.235944 -0.901126 -0.114516  0.634194  0.000000
#
#                7         8         9        10        11
# 0       0.002892 -1.160984 -1.236764 -0.864111 -0.074743
# 1       0.002892 -1.133970 -1.236764 -0.864111 -0.084251
# 2       0.002892 -1.106955 -1.236764 -0.864111 -0.084251
# 3       0.002892 -1.052925 -1.236764 -0.864111 -0.086628
# 4       0.002892 -1.052925 -1.236764 -0.864111 -0.086628
# ...          ...       ...       ...       ...       ...
# 886998  0.002892 -1.160984  2.065920  1.551910  1.657994
# 886999  0.002892 -1.142074  2.065920  1.551910  1.657994
# 887000  0.002892 -1.101552  2.065920  1.551910  1.536298
# 887001  0.002892 -1.074537  2.065920  1.551910  1.512292
# 887002  0.002892 -1.055627  2.065920  1.551910  1.504686
#
# [887003 rows x 12 columns]

# %%
#Change the name of columns back to original names.
df_pipe.columns = df.columns

df_pipe.sample()
# Out:
#         DepthMeters  Salinity  PDensity    RecInd    T_prec    S_prec  \
# 401701      0.14993  0.743222  0.671202 -0.901126 -0.114516  0.634194
#
#             NH3q    MeanAq   R_DYNHT      Year     Month  TempDegF
# 401701  0.176604  0.002892  0.297815 -0.434684  1.853912 -0.583393

# %% [markdown]
# # 5. MODELING

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error


from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
column_names = ["Salinity","TempDegF"]
sal_temp = df.reindex(columns=column_names)

# %%
sal_temp['Salinity'].fillna((sal_temp['Salinity'].mean()), inplace=True)
sal_temp['TempDegF'].fillna((sal_temp['TempDegF'].mean()), inplace=True)

# %% [markdown]
# ## Simple Linear Regression:

# %%
sal_temp.head()
# Out:
#              Salinity  TempDegF
# BottleCount
# 1              33.440    50.900
# 2              33.440    50.828
# 3              33.437    50.828
# 4              33.420    50.810
# 5              33.421    50.810

# %%
X = sal_temp.Salinity.values
y = sal_temp.TempDegF.values

# Print the dimensions of X and y before reshaping
print("Dimensions of y before reshaping: {}".format(y.shape))
print("Dimensions of X before reshaping: {}".format(X.shape))

# Reshape X and y
y = y.reshape(-1,1)
X = X.reshape(-1,1)

# Print the dimensions of X and y after reshaping
print("Dimensions of y after reshaping: {}".format(y.shape))
print("Dimensions of X after reshaping: {}".format(X.shape))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 12)
# Out:
# Dimensions of y before reshaping: (887003,)
# Dimensions of X before reshaping: (887003,)
# Dimensions of y after reshaping: (887003, 1)
# Dimensions of X after reshaping: (887003, 1)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

#Predict the Test set results
y_pred = model.predict(X_test)
# Out:
# LinearRegression()

# %% [markdown]
# #### Visualize the Training set results

# %%
_= plt.scatter(X_train, y_train, color = 'red')
_= plt.plot(X_train, model.predict(X_train), color = 'blue')
_= plt.title('Temperature vs Salinity (Training set)')
_= plt.xlabel('Salinity')
_= plt.ylabel('Temperature')
_= plt.show()

# %% [markdown]
# #### Visualize the Test set results

# %%
_= plt.scatter(X_test, y_test, color = 'red')
_= plt.plot(X_train, model.predict(X_train), color = 'blue')
_= plt.title('Temperature vs Salinity (Training set)')
_= plt.xlabel('Salinity')
_= plt.ylabel('Temperature')
_= plt.show()

# %% [markdown]
# ### Split DataSet to Training set and Test set - For entire Pipeline

# %%
X = df_pipe.drop(['TempDegF'],axis=1).values
y = df_pipe.TempDegF.values

SEED = 42
TS = 0.30

# Create training and test sets
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size = TS, random_state=SEED)

#Feature Scaling to prevent information leakage
#sc = StandardScaler()
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

print (X_train.shape)
print (y_train.shape)

print (X_test.shape)
print (y_test.shape)
# Out:
# (620902, 11)
# (620902,)
# (266101, 11)
# (266101,)

# %% [markdown]
# ## Multiple Linear Regression:

# %%
# Create logistic regression model
linreg = LinearRegression()

# Train the model using the training sets
linreg.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = linreg.predict(X_test)

linreg.score(X_test,y_test)

linreg_training_score = round(linreg.score(X_train, y_train) * 100, 2)
linreg_test_score = round(linreg.score(X_test, y_test) * 100, 2)

print('Linear Regression Training Score: \n', linreg_training_score)
print('Linear Regression Test Score: \n', linreg_test_score)

# Compute and print R^2 and RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error: {}".format(rmse))
# Out:
# LinearRegression()
# 0.8128243925355431
# Linear Regression Training Score:
#  73.33
# Linear Regression Test Score:
#  81.28
# Root Mean Squared Error: 0.43315127212770627

# %%
# 5-fold cross-validation:
cv_scores_5 = cross_val_score(linreg, X, y, cv=5)
print("Average 5-Fold CV Score: {}".format(np.mean(cv_scores_5)))


# 15-fold cross-validation:
cv_scores_15 = cross_val_score(linreg, X, y, cv=15)
print("Average 15-Fold CV Score: {}".format(np.mean(cv_scores_15)))

# 25-fold cross-validation:
cv_scores_25 = cross_val_score(linreg, X, y, cv=25)
print("Average 25-Fold CV Score: {}".format(np.mean(cv_scores_25)))
# Out:
# Average 5-Fold CV Score: 0.2548713529936538
# Average 15-Fold CV Score: 0.2903922119919096
# Average 25-Fold CV Score: 0.6092251340150706

# %% [markdown]
# ## DECISION TREE:

# %%
dtr = DecisionTreeRegressor(random_state=42)
model = dtr.fit(X_train, y_train)

y_pred = model.predict(X_test)


dtr_training_score = round(model.score(X_train, y_train) * 100, 2)
dtr_test_score = round(model.score(X_test, y_test) * 100, 2)

print('Decision Tree Training Score: \n', dtr_training_score)
print('Decision Test Score: \n', dtr_test_score)
# Out:
# Decision Tree Training Score:
#  99.7
# Decision Test Score:
#  99.36

# %% [markdown]
# ## RANDOM FOREST:

# %%
rfr = RandomForestRegressor(random_state=0, n_jobs=-1)
model = rfr.fit(X_train, y_train)
y_pred = model.predict(X_test)

rfr_training_score = round(model.score(X_train, y_train) * 100, 2)
rfr_test_score = round(model.score(X_test, y_test) * 100, 2)

print('Random Forest Training Score: \n', rfr_training_score)
print('Random Forest Test Score: \n', rfr_test_score)
# Out:
# Random Forest Training Score:
#  99.68
# Random Forest Test Score:
#  99.48

# %%
models = pd.DataFrame({
    
    'Model': [ 
        'Linear Regression',
        'Decision Tree',
        'Random Forest',   
    ],
             
    
    'Training Score': [ 
        linreg_training_score,
        dtr_training_score, 
        rfr_training_score,
    ],
    
    'Test Score': [ 
        linreg_test_score,
        dtr_test_score,
        rfr_test_score,
    ]})


models.sort_values(by='Test Score', ascending=False)
# Out:
#                Model  Training Score  Test Score
# 2      Random Forest           99.68       99.48
# 1      Decision Tree           99.70       99.36
# 0  Linear Regression           73.33       81.28

# %% [markdown]
# # 6. DOCUMENTATION

# %% [markdown]
# ### Summary
# This is Supervised Regression project to analyze Oceanographic trends.
#
# Temperature (TempDegF) is the target variable. Celsius was converted to Fahrenheit.
#
# ### Model Performance:
# Accuracy Score: R^2: was used to determine the best model.
#
# ### Model Findings:
# The most important features where:
# - 1. Salinity()
# - 2. Temperature()
#
# The reported Dynamic Height improved the model was removed then added to model because it improved the R^2 score significantly.

# %% [markdown]
# ## EXPORT DATA...

# %%
#df.to_csv('../data/calcofi/wrangle_csv.csv', index=True)
